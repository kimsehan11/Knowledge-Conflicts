# %%
import http.client
import json
from dotenv import load_dotenv
import os
import requests

load_dotenv()
# Out:
# True

# %%
def search_serper(query, pages=3):
    all_results = []
    for page in range(1, pages + 1):
        conn = http.client.HTTPSConnection("google.serper.dev")
        payload = json.dumps({"q": query, "page": page})
        headers = {
            'X-API-KEY': os.getenv("SERPER_API_KEY"),
            'Content-Type': 'application/json'
        }
        conn.request("POST", "/search", payload, headers)
        res = conn.getresponse()
        data = json.loads(res.read().decode("utf-8"))
        all_results.extend(data.get("organic", []))
    return all_results

# %%
from bs4 import BeautifulSoup

def is_accessible(url, timeout=10):
    try:
        r = requests.get(url, timeout=timeout, allow_redirects=True,
                        headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'})
        return r.status_code == 200, r.text
    except:
        return False, None

def extract_paragraph(html, snippet):
    soup = BeautifulSoup(html, 'html.parser')
    text = soup.get_text()
    sentences = text.replace('\n', ' ').split('.')
    
    keywords = snippet.replace('...', '').strip().split()[:5]
    keyword_str = ' '.join(keywords)
    
    for sentence in sentences:
        if keyword_str in sentence:
            return sentence.strip() + '.'
    return snippet

# %%
def get_accessible_results(query, target=10, pages=3):
    results = search_serper(query, pages)
    accessible = []
    for r in results:
        if len(accessible) >= target:
            break
        success, html = is_accessible(r["link"])
        if success:
            r["paragraph"] = extract_paragraph(html, r["snippet"])
            accessible.append(r)
    return accessible

# %%
from prompt_template import RAG_PROMPT_TEMPLATE
from langchain_core.prompts import PromptTemplate 
from model import llm_answer

def web_rag(query, llm, target=10):
    RAG_PROMPT = PromptTemplate(
        template=RAG_PROMPT_TEMPLATE,
        input_variables=["context", "question"]
    )

    docs = get_accessible_results(query, target=target, pages=3)
    context = "\n\n".join([f"[{i+1}] {doc['title']}\n{doc['paragraph']}" for i, doc in enumerate(docs)])
    prompt = RAG_PROMPT.format(context=context, question=query)
    response = llm_answer(llm[0], llm[1], prompt)
    
    return {
        "query": query,
        "answer": response,
        "source_documents": docs
    }

# %%
# 이 부분은 테스트하는 main.py 코드로 갈듯듯 
from model import llm_load

llm = llm_load()
# Out:
# Loading checkpoint shards: 100%|██████████| 5/5 [00:45<00:00,  9.04s/it]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
result = web_rag("What is Eleanor Davis's occupation?", llm)
result
# Out:
# {'query': "What is Eleanor Davis's occupation?",
#  'answer': ' Eleanor Davis is a cartoonist and illustrator.',
#  'source_documents': [{'title': 'Eleanor Davis',
#    'link': 'https://en.wikipedia.org/wiki/Eleanor_Davis',
#    'snippet': 'Eleanor McCutcheon Davis (born January 16, 1983) is an American cartoonist and illustrator. Davis and Jillian Tamaki in discussion, 2017',
#    'position': 1,
#    'paragraph': 'com/ Davis and Jillian Tamaki in discussion, 2017 Eleanor McCutcheon Davis (born January 16, 1983) is an American cartoonist and illustrator.'},
#   {'title': 'About / Contact',
#    'link': 'https://doing-fine.com/?page_id=2',
#    'snippet': "I'm a cartoonist and illustrator. My books include How To Be Happy, You and a Bike and a Road, Why Art? and The Secret Science Alliance and the Copycat Crook.",
#    'position': 2,
#    'paragraph': "I'm a cartoonist and illustrator. My books include How To Be Happy, You and a Bike and a Road, Why Art? and The Secret Science Alliance and the Copycat Crook."},
#   {'title': "It's a colorful life: Award-winning illustrator Eleanor Davis ...",
#    'link': 'https://www.redandblack.com/culture/its-a-colorful-life-award-winning-illustrator-eleanor-davis-brightens-athens/article_74da3662-487f-11ea-8ee6-2b25b72652e1.html',
#    'snippet': "An award-winning illustrator of both adult and children's comics, Davis is a quiet artistic force in Athens. Her work, which spans short comics ...",
#    'date': 'Feb 6, 2020',
#    'position': 3,
#    'paragraph': "An award-winning illustrator of both adult and children's comics, Davis is a quiet artistic force in Athens. Her work, which spans short comics ..."},
#   {'title': 'Q&A with author, cartoonist and illustrator Eleanor Davis',
#    'link': 'https://odysseynewsmagazine.net/2022/04/17/cool-comics-qa-with-author-cartoonist-and-illustrator-eleanor-davis/',
#    'snippet': 'Author, cartoonist and illustrator Eleanor Davis: Before (my career) I was just really interested in comics. I had been reading and drawing ...',
#    'date': 'Apr 17, 2022',
#    'position': 4,
#    'paragraph': 'Variety staffer Isabella Westrich: What can you tell me about your journey with illustrations and cartoons? Author, cartoonist and illustrator Eleanor Davis: Before (my career) I was just really interested in comics.'},
#   {'title': 'Deacon Spotlight: Eleanor Scott Davis',
#    'link': 'https://alumni.opcd.wfu.edu/deacon-spotlight/deacon-spotlight-eleanor-scott-davis/',
#    'snippet': 'My day-to-day life is a balancing act of working as a professional artist and a stay-at-home mom. I am lucky to have my studio in my home so, I am able to fit ...',
#    'position': 5,
#    'paragraph': 'My day-to-day life is a balancing act of working as a professional artist and a stay-at-home mom.'},
#   {'title': 'A conversation with cartoonist and author Eleanor Davis',
#    'link': 'https://www.artsatl.org/conversation-cartoonist-author-eleanor-davis/',
#    'snippet': 'Eleanor Davis is an award-winning cartoonist who lives in Athens, Georgia. Her fourth book is You & a Bike & a Road (Koyoma Press, 172 pp), a journal of her ...',
#    'date': 'May 22, 2017',
#    'position': 6,
#    'paragraph': 'Eleanor Davis is an award-winning cartoonist who lives in Athens, Georgia.'},
#   {'title': 'Do comics for yourself; do something else to make money',
#    'link': 'https://eng.bantmag.com/2017/12/19/eleanor-davis-do-comics-for-yourself-do-something-else-to-make-money/',
#    'snippet': "These days it's rare to make a living from making comics, but Eleanor Davis does just that. Her work, which can be seen in prestigious media ...",
#    'date': 'Dec 19, 2017',
#    'position': 7,
#    'paragraph': "These days it's rare to make a living from making comics, but Eleanor Davis does just that. Her work, which can be seen in prestigious media ..."},
#   {'title': 'Eleanor Davis – Drawn & Quarterly',
#    'link': 'https://drawnandquarterly.com/author/eleanor-davis/',
#    'snippet': 'Eleanor Davis is a cartoonist and illustrator. Her books include How To Be Happy, You and a Bike and a Road, Why Art? and The Secret Science Alliance and ...',
#    'position': 8,
#    'paragraph': 'BooksAuthorsNewsPressEventsAboutMy AccountVisit Montreal Bookstore                                                              Generic selectors       \t\t\t\tExact matches only\t\t\t        \t\t\t\tSearch in title\t\t\t        \t\t\t\tSearch in content\t\t\t        Post Type Selectors        NEW RELEASESMemoirFictionNon-fictionMangaManhwaMoominKidsEleanor DavisEleanor Davis is a cartoonist and illustrator.'},
#   {'title': 'The Center for Cartoon Studies - Facebook',
#    'link': 'https://www.facebook.com/cartoonstudies/posts/this-years-eisner-lecturer-was-the-inimitable-eleanor-davis-squinkyelo-is-an-awa/1758784525009258/',
#    'snippet': "This year's Eisner Lecturer was the inimitable Eleanor Davis! @squinkyelo is an award winning cartoonist and illustrator whose comics and graphic novels ...",
#    'date': '8 months ago',
#    'position': 9,
#    'paragraph': "This year's Eisner Lecturer was the inimitable Eleanor Davis! @squinkyelo is an award winning cartoonist and illustrator whose comics and graphic novels ..."},
#   {'title': 'Episode 19 + 20: NYT Bestselling Illustrator, Eleanor Davis',
#    'link': 'https://contentisqueen.org/show-notes/nyt-bestselling-illustrator-eleanor-davis/',
#    'snippet': "This week I'm joined by Illustrator and Cartoonist Eleanor Davis. Eleanor is the author of New York Times Bestseller How To Be Happy, among ...",
#    'date': 'Jan 11, 2026',
#    'position': 10,
#    'paragraph': "This week I'm joined by Illustrator and Cartoonist Eleanor Davis. Eleanor is the author of New York Times Bestseller How To Be Happy, among ..."}]}
